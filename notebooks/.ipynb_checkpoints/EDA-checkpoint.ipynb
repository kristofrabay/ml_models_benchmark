# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/diamonds.csv')

# drop original index column
data.drop('Unnamed: 0', 1, inplace = True)

data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
numerics = data.select_dtypes(include = 'number').columns.tolist()
categoricals = data.select_dtypes(include = ['object', 'category']).columns.tolist()

print('Numeric features:', ', '.join(numerics))
print('Categorical features:', ', '.join(categoricals))
# Out:
# Numeric features: carat, depth, table, price, x, y, z
# Categorical features: cut, color, clarity

# %% [markdown]
# ### 1. Check missing (NaN, null, inf) values

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ### 2. Explore target variable (price)

# %%
fig, ax = plt.subplots(figsize = (15, 3), ncols = 3)

sns.distplot(data['price'], kde = False, ax = ax[0])
sns.distplot(np.sqrt(data['price']), kde = False, ax = ax[1])
sns.distplot(np.log(data['price']), kde = False, ax = ax[2])

ax[0].set_title('Original price feature')
ax[1].set_title('Square root of price')
ax[2].set_title('Natural logarithm of price')

ax[1].set_xlabel('sqrt(price)')
ax[2].set_xlabel('log(price)')

plt.show()

# %% [markdown]
# Seems there are no outliers, but the data is very skewed to the right. Normally would decide to predict the log or sqrt of y in order to force the target distribution to be more similar to a Gaussian. This time tho, as I'm running multiple models (linear regression, knn, svm, trees) I will leave it as is and see which models take better care of the log-normal looking curve

# %% [markdown]
# ### 3. Explore categorical features

# %%
data.describe(include = 'object')
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# #### Cut

# %%
data['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# <img src="https://diamondbuzz.blog/wp-content/uploads/2019/05/Diamond-Cut-Grades.jpg" style="width: 250px;"/>

# %% [markdown]
# #### Color

# %%
data['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %% [markdown]
# <img src="https://beyond4cs.com/wp-content/uploads/2019/02/diamond-color-chart-with-example-diamonds-of-each-alphabet.jpg" style="width: 600px;"/>

# %% [markdown]
# #### Clarity

# %%
data['clarity'].value_counts()
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %% [markdown]
# <img src="https://selectingadiamond.com/wp-content/uploads/2019/10/Diamond-Clarity.jpg" style="width: 600px;"/>

# %% [markdown]
# #### Impact on price distributions

# %%
fig, ax = plt.subplots(figsize = (15, 3), ncols = 3)
sns.boxenplot(x = 'cut', y = 'price', data = data, order = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], color = 'skyblue', ax = ax[0])
sns.boxenplot(x = 'color', y = 'price', data = data, order = ['D', 'E', 'F', 'G', 'H', 'I', 'J'], color = 'skyblue', ax = ax[1])
sns.boxenplot(x = 'clarity', y = 'price', data = data, order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'], color = 'skyblue', ax = ax[2])
plt.tight_layout()
plt.show()

# %% [markdown]
# Price per carat

# %%
fig, ax = plt.subplots(figsize = (15, 3), ncols = 3)
sns.boxenplot(x = 'cut', y = data['price'] / data['carat'], data = data, order = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], color = 'skyblue', ax = ax[0])
sns.boxenplot(x = 'color', y = data['price'] / data['carat'], data = data, order = ['D', 'E', 'F', 'G', 'H', 'I', 'J'], color = 'skyblue', ax = ax[1])
sns.boxenplot(x = 'clarity', y = data['price'] / data['carat'], data = data, order = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'], color = 'skyblue', ax = ax[2])
plt.tight_layout()
plt.show()

# %% [markdown]
# Price distributions with kde plots

# %%
fig, ax = plt.subplots(figsize = (7, 12), nrows = 3)

for i in data['cut'].unique():
    sns.distplot(data[data['cut'] == i]['price'], hist = False, label = i, kde_kws = {'linewidth' : 2.5}, ax = ax[0])
    
for i in data['color'].unique():
    sns.distplot(data[data['color'] == i]['price'], hist = False, label = i, kde_kws = {'linewidth' : 2.5}, ax = ax[1])
    
for i in data['clarity'].unique():
    sns.distplot(data[data['clarity'] == i]['price'], hist = False, label = i, kde_kws = {'linewidth' : 2.5}, ax = ax[2])
    
plt.show()

# %% [markdown]
# ### 4. Explore numeric features

# %% [markdown]
# #### Distributions

# %%
g = sns.FacetGrid(data[numerics].melt(), col = 'variable', sharex = False, sharey = False, col_wrap = 4, height = 3, aspect = 4/3)
g.map(sns.distplot, 'value', kde = False)

plt.show()

# %%
print('Original number of observations:', data.shape[0])

data = data[(data['x'] > 3) & (data['y'] < 15) & (data['z'] < 10) & (data['z'] > 2) &
            (data['y'] != 0) & (data['z'] != 0) &
            (data['table'] < 70) & (data['table'] > 50) &
            (data['depth'] > 55) & (data['depth'] < 68.5) &
            (data['carat'] <= 3)]

print('After applying filters on numeric features:', data.shape[0])
# Out:
# Original number of observations: 53940
# After applying filters on numeric features: 53770

# %%
g = sns.FacetGrid(data[numerics].melt(), col = 'variable', sharex = False, sharey = False, col_wrap = 4, height = 3, aspect = 4/3)
g.map(sns.distplot, 'value', kde = False)

plt.show()

# %% [markdown]
# #### Correlations

# %%
fig, ax = plt.subplots(figsize = (7, 3))
sns.heatmap(data.corr(), ax = ax, cmap = 'coolwarm', center = 0, annot = True, fmt = '.3g')
plt.title('Lot of high positive correlations to explore\n')
plt.show()

# %%
sns.pairplot(data)

# %% [markdown]
# Plot x, y and z in 3d and color by price, carat

# %%
fig = plt.figure(figsize = (8, 5))
ax = Axes3D(fig)

sc = ax.scatter(xs = data['x'], ys = data['y'], zs = data['z'], s = 5, c = data['price'], marker = 'o', alpha = 1)
ax.set_xlabel('X - length')
ax.set_ylabel('Y - width')
ax.set_zlabel('Z - depth')

plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.title('Price does increase with size - in any dimension')
plt.show()

# %%
fig = plt.figure(figsize = (8, 5))
ax = Axes3D(fig)

sc = ax.scatter(xs = data['x'], ys = data['y'], zs = data['z'], s = 5, c = data['carat'], marker = 'o', alpha = 1)
ax.set_xlabel('X - length')
ax.set_ylabel('Y - width')
ax.set_zlabel('Z - depth')

plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
plt.title('Carat is also - correctly - dependant of size')
plt.show()

# %% [markdown]
# Decisions:
# 1. Multiply x-y-z and create a 'volume' feature, then drop originals
# 2. Take square of carat too
#
# #### RESULT: high correlations remain, drop x, y, z and squared features

# %%
data_original = data.copy()

# %%
data['x*y*z'] = data['x'] * data['y'] * data['z']

data['x_ratio'] = data['x'] / data['x*y*z']
data['y_ratio'] = data['y'] / data['x*y*z']
data['z_ratio'] = data['z'] / data['x*y*z']

data['carat2'] = np.square(data['carat'])

data.drop(['x', 'y', 'z', 'x*y*z'], 1, inplace = True)

# %%
fig, ax = plt.subplots(figsize = (7, 3))
sns.heatmap(data.corr(), ax = ax, cmap = 'coolwarm', center = 0, annot = True, fmt = '.2g')
plt.title('\n')
plt.show()

# %% [markdown]
# x, y and z ratios are unusable

# %%
data.drop(['x_ratio', 'y_ratio', 'z_ratio', 'carat2'], 1, inplace = True)

# %%
fig, ax = plt.subplots(figsize = (7, 3))
sns.heatmap(data.corr(), ax = ax, cmap = 'coolwarm', center = 0, annot = True, fmt = '.2g')
plt.title('\n')
plt.show()

# %%
sns.pairplot(data)

# %% [markdown]
# #### Take a final look, save to csv

# %%
data.head()
# Out:
#    carat      cut color clarity  depth  table  price
# 0   0.23    Ideal     E     SI2   61.5   55.0    326
# 1   0.21  Premium     E     SI1   59.8   61.0    326
# 2   0.23     Good     E     VS1   56.9   65.0    327
# 3   0.29  Premium     I     VS2   62.4   58.0    334
# 4   0.31     Good     J     SI2   63.3   58.0    335

# %%
data.to_csv('../data/diamonds_cleaned.csv', index = False)
